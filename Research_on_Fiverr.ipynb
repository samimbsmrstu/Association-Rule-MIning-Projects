# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import squarify
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
dataset = pd.read_excel('G:/4-1 Thesis/fiverr_thesis.xlsx')

# %%
dataset.head()
# Out:
#     fiverr_profile                                 Category  \
# 0          aaimran                            Data,Business
# 1         aaliyaan     Programming & Tech,Digital Marketing
# 2     abantikabose  Digital Marketing,Writing & Translation
# 3     abdelhamid19                        Digital Marketing
# 4  abidhussain1918          Digital Marketing,Data,Business
#
#                                          Subcategory              Pricing  \
# 0   Data Processing,Data Entry,E-Commerce Management             10,10,10
# 1  E-Commerce Development,WordPress,Video Marketi...  145,45,30,20,20,145
# 2  Book & eBook Marketing,Book & eBook Writing,Bo...          25,30,10,50
# 3                          Web Analytics,Web Traffic               100,70
# 4  Influencer Marketing,Data Processing,Data Entr...           5,10,10,10
#
#                  Sales              Stars
# 0             15,242,1          4.9,4.9,5
# 1  1,331,129,560,516,3  5,5,4.9,4.9,4.9,5
# 2        162,79,334,29          5,4.9,5,5
# 3                 3,74                5,5
# 4            1,16,73,2        5,4.9,4.9,5

# %%
dataset['Category'].isnull().sum()
# Out:
# 0

# %%
print(dataset.shape)
#print(dataset.columns) 
#print(dataset.head(10))
#print(dataset.describe())
# Out:
# (1500, 6)

# %% [markdown]
# # Category Part

# %%
column_list_category = []
for index, rows in dataset.iterrows():
    my_string = rows.Category
    my_list = my_string.split(",")
    column_list_category.append(my_list)
#print(column_list_category)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
tran_encod = TransactionEncoder()
tran_encod_list = tran_encod.fit(column_list_category).transform(column_list_category)
transaction_df_cat = pd.DataFrame(tran_encod_list, columns=tran_encod.columns_)
transaction_df_cat.head()
# Out:
#    Business   Data  Digital Marketing  Graphics & Design  Lifestyle  \
# 0      True   True              False              False      False
# 1     False  False               True              False      False
# 2     False  False               True              False      False
# 3     False  False               True              False      False
# 4      True   True               True              False      False
#
#    Music & Audio  Programming & Tech  Video & Animation  Writing & Translation
# 0          False               False              False                  False
# 1          False                True              False                  False
# 2          False               False              False                   True
# 3          False               False              False                  False
# 4          False               False              False                  False

# %%
item_count = {}
for col in transaction_df_cat.columns:
    item_count[col] = transaction_df_cat[col].sum()
item_freq_df_cat = pd.DataFrame(data=list(item_count.values()), index=list(item_count.keys()), columns=['frequency']).sort_values(by='frequency', ascending=False)
item_freq_df_cat.shape, item_freq_df_cat.head(9)
# Out:
# ((9, 1),
#                         frequency
#  Programming & Tech           585
#  Digital Marketing            561
#  Graphics & Design            558
#  Writing & Translation        327
#  Data                         261
#  Business                     231
#  Video & Animation            216
#  Music & Audio                 69
#  Lifestyle                     36)

# %%
plt.figure(figsize=(16,7))
sns.barplot(y=item_freq_df_cat.index[:9], x=item_freq_df_cat.frequency[:9])
plt.xticks(rotation=90)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600., 700.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
apriori(transaction_df_cat, min_support=0.1, use_colnames=True)
# Out:
#    support                                    itemsets
# 0    0.154                                  (Business)
# 1    0.174                                      (Data)
# 2    0.374                         (Digital Marketing)
# 3    0.372                         (Graphics & Design)
# 4    0.390                        (Programming & Tech)
# 5    0.144                         (Video & Animation)
# 6    0.218                     (Writing & Translation)
# 7    0.146     (Digital Marketing, Programming & Tech)
# 8    0.110  (Digital Marketing, Writing & Translation)
# 9    0.108     (Programming & Tech, Graphics & Design)

# %%
#print(f'freq>30: {item_freq_df_cat[item_freq_df_cat.frequency>30].shape[0]} items')
#print(f'freq>20: {item_freq_df_cat[item_freq_df_cat.frequency>20].shape[0]} items')
#print(f'freq>12: {item_freq_df_cat[item_freq_df_cat.frequency>12].shape[0]} items')

# %%
freq_itemset_support = apriori(transaction_df_cat, min_support=0.024, use_colnames=True)
freq_itemset_support
# Out:
#     support                                           itemsets
# 0     0.154                                         (Business)
# 1     0.174                                             (Data)
# 2     0.374                                (Digital Marketing)
# 3     0.372                                (Graphics & Design)
# 4     0.024                                        (Lifestyle)
# 5     0.046                                    (Music & Audio)
# 6     0.390                               (Programming & Tech)
# 7     0.144                                (Video & Animation)
# 8     0.218                            (Writing & Translation)
# 9     0.066                                   (Business, Data)
# 10    0.074                      (Digital Marketing, Business)
# 11    0.044                      (Business, Graphics & Design)
# 12    0.054                     (Business, Programming & Tech)
# 13    0.052                  (Writing & Translation, Business)
# 14    0.044                          (Digital Marketing, Data)
# 15    0.024                          (Graphics & Design, Data)
# 16    0.088                         (Programming & Tech, Data)
# 17    0.040                      (Writing & Translation, Data)
# 18    0.076             (Digital Marketing, Graphics & Design)
# 19    0.146            (Digital Marketing, Programming & Tech)
# 20    0.026             (Video & Animation, Digital Marketing)
# 21    0.110         (Digital Marketing, Writing & Translation)
# 22    0.108            (Programming & Tech, Graphics & Design)
# 23    0.076             (Video & Animation, Graphics & Design)
# 24    0.052         (Writing & Translation, Graphics & Design)
# 25    0.030            (Video & Animation, Programming & Tech)
# 26    0.058        (Writing & Translation, Programming & Tech)
# 27    0.028               (Programming & Tech, Business, Data)
# 28    0.026  (Digital Marketing, Business, Programming & Tech)
# 29    0.032  (Digital Marketing, Writing & Translation, Bus...
# 30    0.036  (Digital Marketing, Programming & Tech, Graphi...
# 31    0.030  (Digital Marketing, Writing & Translation, Gra...
# 32    0.034  (Digital Marketing, Writing & Translation, Pro...

# %%
overal_association_rules = association_rules(freq_itemset_support, metric="confidence", min_threshold=0.50)
overal_association_rules
# Out:
#                                    antecedents           consequents  \
# 0                                       (Data)  (Programming & Tech)
# 1                      (Writing & Translation)   (Digital Marketing)
# 2                          (Video & Animation)   (Graphics & Design)
# 3               (Business, Programming & Tech)                (Data)
# 4            (Writing & Translation, Business)   (Digital Marketing)
# 5   (Writing & Translation, Graphics & Design)   (Digital Marketing)
# 6  (Writing & Translation, Programming & Tech)   (Digital Marketing)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0               0.174               0.390    0.088    0.505747  1.296788
# 1               0.218               0.374    0.110    0.504587  1.349164
# 2               0.144               0.372    0.076    0.527778  1.418757
# 3               0.054               0.174    0.028    0.518519  2.979991
# 4               0.052               0.374    0.032    0.615385  1.645413
# 5               0.052               0.374    0.030    0.576923  1.542575
# 6               0.058               0.374    0.034    0.586207  1.567398
#
#    leverage  conviction
# 0  0.020140    1.234186
# 1  0.028468    1.263593
# 2  0.022432    1.329882
# 3  0.018604    1.715538
# 4  0.012552    1.627600
# 5  0.010552    1.479636
# 6  0.012308    1.512833

# %%
#overal_association_rules = association_rules(freq_itemset_support, metric="lift", min_threshold=1.0)
#overal_association_rules
plt.figure(figsize=(10,6))
sns.scatterplot(x = "support", y = "confidence", data = overal_association_rules)
plt.margins(0.01,0.01)
plt.show()

# %%
# Convert antecedents and consequents into strings
overal_association_rules['antecedents'] = overal_association_rules['antecedents'].apply(lambda a: ','.join(list(a)))
overal_association_rules['consequents'] = overal_association_rules['consequents'].apply(lambda a: ','.join(list(a)))

# Transform antecedent, consequent, and support columns into matrix
support_table = overal_association_rules.pivot(index='consequents', columns='antecedents', values='support')

plt.figure(figsize=(10,6))
sns.heatmap(support_table, annot=True, cbar=False)
b, t = plt.ylim() 
b += 0.5 
t -= 0.5 
plt.ylim(b, t) 
plt.yticks(rotation=0)
plt.show()

# %%
import networkx as nx
fig, ax=plt.subplots(figsize=(40,15))
GA=nx.from_pandas_edgelist(overal_association_rules,source='antecedents',target='consequents')
nx.draw(GA,with_labels=True)
plt.show()

# %%
overal_association_rules.sort_values('confidence', ascending=False)
# Out:
#                                 antecedents         consequents  \
# 4            Writing & Translation,Business   Digital Marketing
# 6  Writing & Translation,Programming & Tech   Digital Marketing
# 5   Writing & Translation,Graphics & Design   Digital Marketing
# 2                         Video & Animation   Graphics & Design
# 3               Business,Programming & Tech                Data
# 0                                      Data  Programming & Tech
# 1                     Writing & Translation   Digital Marketing
#
#    antecedent support  consequent support  support  confidence      lift  \
# 4               0.052               0.374    0.032    0.615385  1.645413
# 6               0.058               0.374    0.034    0.586207  1.567398
# 5               0.052               0.374    0.030    0.576923  1.542575
# 2               0.144               0.372    0.076    0.527778  1.418757
# 3               0.054               0.174    0.028    0.518519  2.979991
# 0               0.174               0.390    0.088    0.505747  1.296788
# 1               0.218               0.374    0.110    0.504587  1.349164
#
#    leverage  conviction
# 4  0.012552    1.627600
# 6  0.012308    1.512833
# 5  0.010552    1.479636
# 2  0.022432    1.329882
# 3  0.018604    1.715538
# 0  0.020140    1.234186
# 1  0.028468    1.263593

# %%
#overal_association_rules.sort_values('lift', ascending=False)

# %% [markdown]
# # Using FP-Growth

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
transaction_df_cat.head()
# Out:
#    Business   Data  Digital Marketing  Graphics & Design  Lifestyle  \
# 0      True   True              False              False      False
# 1     False  False               True              False      False
# 2     False  False               True              False      False
# 3     False  False               True              False      False
# 4      True   True               True              False      False
#
#    Music & Audio  Programming & Tech  Video & Animation  Writing & Translation
# 0          False               False              False                  False
# 1          False                True              False                  False
# 2          False               False              False                   True
# 3          False               False              False                  False
# 4          False               False              False                  False

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth_frequent_itemset = fpgrowth(transaction_df_cat, min_support=0.024, use_colnames=True)
fpgrowth_frequent_itemset
# Out:
#     support                                           itemsets
# 0     0.174                                             (Data)
# 1     0.154                                         (Business)
# 2     0.390                               (Programming & Tech)
# 3     0.374                                (Digital Marketing)
# 4     0.218                            (Writing & Translation)
# 5     0.372                                (Graphics & Design)
# 6     0.144                                (Video & Animation)
# 7     0.046                                    (Music & Audio)
# 8     0.024                                        (Lifestyle)
# 9     0.044                          (Digital Marketing, Data)
# 10    0.040                      (Writing & Translation, Data)
# 11    0.088                         (Programming & Tech, Data)
# 12    0.024                          (Graphics & Design, Data)
# 13    0.066                                   (Business, Data)
# 14    0.074                      (Digital Marketing, Business)
# 15    0.054                     (Business, Programming & Tech)
# 16    0.044                      (Business, Graphics & Design)
# 17    0.052                  (Writing & Translation, Business)
# 18    0.026  (Digital Marketing, Business, Programming & Tech)
# 19    0.028               (Programming & Tech, Business, Data)
# 20    0.032  (Digital Marketing, Writing & Translation, Bus...
# 21    0.146            (Digital Marketing, Programming & Tech)
# 22    0.110         (Digital Marketing, Writing & Translation)
# 23    0.058        (Writing & Translation, Programming & Tech)
# 24    0.052         (Writing & Translation, Graphics & Design)
# 25    0.034  (Digital Marketing, Writing & Translation, Pro...
# 26    0.030  (Digital Marketing, Writing & Translation, Gra...
# 27    0.108            (Programming & Tech, Graphics & Design)
# 28    0.076             (Digital Marketing, Graphics & Design)
# 29    0.036  (Digital Marketing, Programming & Tech, Graphi...
# 30    0.076             (Video & Animation, Graphics & Design)
# 31    0.030            (Video & Animation, Programming & Tech)
# 32    0.026             (Video & Animation, Digital Marketing)

# %%
fpgrowth_association_rules = association_rules(fpgrowth_frequent_itemset, metric="confidence", min_threshold=0.50)
fpgrowth_association_rules
# Out:
#                                    antecedents           consequents  \
# 0                                       (Data)  (Programming & Tech)
# 1               (Business, Programming & Tech)                (Data)
# 2            (Writing & Translation, Business)   (Digital Marketing)
# 3                      (Writing & Translation)   (Digital Marketing)
# 4  (Writing & Translation, Programming & Tech)   (Digital Marketing)
# 5   (Writing & Translation, Graphics & Design)   (Digital Marketing)
# 6                          (Video & Animation)   (Graphics & Design)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0               0.174               0.390    0.088    0.505747  1.296788
# 1               0.054               0.174    0.028    0.518519  2.979991
# 2               0.052               0.374    0.032    0.615385  1.645413
# 3               0.218               0.374    0.110    0.504587  1.349164
# 4               0.058               0.374    0.034    0.586207  1.567398
# 5               0.052               0.374    0.030    0.576923  1.542575
# 6               0.144               0.372    0.076    0.527778  1.418757
#
#    leverage  conviction
# 0  0.020140    1.234186
# 1  0.018604    1.715538
# 2  0.012552    1.627600
# 3  0.028468    1.263593
# 4  0.012308    1.512833
# 5  0.010552    1.479636
# 6  0.022432    1.329882

# %% [markdown]
# # Sub Category Part

# %%
column_list_subcategory = []
for index, rows in dataset.iterrows():
    my_string = rows.Subcategory
    my_list = my_string.split(",")
    column_list_subcategory.append(my_list)
#print(column_list)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
tran_encod = TransactionEncoder()
tran_encod_list = tran_encod.fit(column_list_subcategory).transform(column_list_subcategory)
transaction_df_subcat = pd.DataFrame(tran_encod_list, columns=tran_encod.columns_)
transaction_df_subcat.head()
# Out:
#    Ad Copy  Affiliate Marketing  Album Cover Design  Animated GIFs  \
# 0    False                False               False          False
# 1    False                False               False          False
# 2    False                False               False          False
# 3    False                False               False          False
# 4    False                False               False          False
#
#    Animation for Kids  Animation for Streamers  App & Website Previews  \
# 0               False                    False                   False
# 1               False                    False                   False
# 2               False                    False                   False
# 3               False                    False                   False
# 4               False                    False                   False
#
#    App Design  Architecture & Interior Design  Articles & Blog Posts  ...  \
# 0       False                           False                  False  ...
# 1       False                           False                  False  ...
# 2       False                           False                  False  ...
# 3       False                           False                  False  ...
# 4       False                           False                  False  ...
#
#    Web Traffic  Website Builders & CMS  Website Content  Website Design  \
# 0        False                   False            False           False
# 1        False                   False            False           False
# 2        False                   False            False           False
# 3         True                   False            False           False
# 4        False                   False            False           False
#
#    Wellness  Whiteboard & Animated Explainers  WordPress  Wordpress  \
# 0     False                             False      False      False
# 1     False                             False       True      False
# 2     False                             False      False      False
# 3     False                             False      False      False
# 4     False                             False      False      False
#
#    eLearning Content Development  eLearning Video Production
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
#
# [5 rows x 176 columns]

# %%
item_count = {}
for col in transaction_df_subcat.columns:
    item_count[col] = transaction_df_subcat[col].sum()
item_freq_df_subcat = pd.DataFrame(data=list(item_count.values()), index=list(item_count.keys()), columns=['frequency']).sort_values(by='frequency', ascending=False)
item_freq_df_subcat.shape, item_freq_df_subcat.head()
# Out:
# ((176, 1),
#                                    frequency
#  Logo Design                             243
#  WordPress                               225
#  Social Media Marketing                  174
#  Search Engine Optimization (SEO)        162
#  Other                                   144)

# %%
plt.figure(figsize=(16,7))
sns.barplot(y=item_freq_df_subcat.index[:15], x=item_freq_df_subcat.frequency[:15])
plt.xticks(rotation=90)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
apriori(transaction_df_subcat, min_support=0.1, use_colnames=True)
# Out:
#    support                            itemsets
# 0    0.162                       (Logo Design)
# 1    0.108  (Search Engine Optimization (SEO))
# 2    0.116            (Social Media Marketing)
# 3    0.150                         (WordPress)

# %%
print(f'freq>41: {item_freq_df_subcat[item_freq_df_subcat.frequency>41].shape[0]} items')
print(f'freq>30: {item_freq_df_subcat[item_freq_df_subcat.frequency>29].shape[0]} items')
print(f'freq>15: {item_freq_df_subcat[item_freq_df_subcat.frequency>15].shape[0]} items')
# Out:
# freq>41: 50 items
# freq>30: 59 items
# freq>15: 83 items

# %%
freq_itemset_support = apriori(transaction_df_subcat, min_support=0.02, use_colnames=True)
freq_itemset_support.head(60)
# Out:
#     support                                  itemsets
# 0     0.028                              (App Design)
# 1     0.082                   (Articles & Blog Posts)
# 2     0.062                  (Book & eBook Marketing)
# 3     0.030                    (Book & eBook Writing)
# 4     0.042                             (Book Design)
# 5     0.050                      (Brand Style Guides)
# 6     0.032                         (Brochure Design)
# 7     0.040             (Business Cards & Stationery)
# 8     0.022                     (Business Consulting)
# 9     0.032                       (Content Marketing)
# 10    0.032                           (Convert Files)
# 11    0.092                              (Data Entry)
# 12    0.034                         (Data Processing)
# 13    0.054                            (Data Science)
# 14    0.034                      (Data Visualization)
# 15    0.024                               (Databases)
# 16    0.038                    (Desktop Applications)
# 17    0.068                  (E-Commerce Development)
# 18    0.030                   (E-Commerce Management)
# 19    0.038                    (E-Commerce Marketing)
# 20    0.054                            (Flyer Design)
# 21    0.022                                (Game Art)
# 22    0.030                        (Game Development)
# 23    0.032                  (Graphics for Streamers)
# 24    0.034                            (Illustration)
# 25    0.020                    (Influencer Marketing)
# 26    0.022                         (Intros & Outros)
# 27    0.162                             (Logo Design)
# 28    0.032                         (Market Research)
# 29    0.038                      (Marketing Strategy)
# 30    0.054                    (Mobile App Marketing)
# 31    0.068                             (Mobile Apps)
# 32    0.096                                   (Other)
# 33    0.020                (Packaging & Label Design)
# 34    0.030                       (Photoshop Editing)
# 35    0.020                     (Presentation Design)
# 36    0.024                    (Product Descriptions)
# 37    0.030                  (Proofreading & Editing)
# 38    0.034                                   (Sales)
# 39    0.034           (Search Engine Marketing (SEM))
# 40    0.108        (Search Engine Optimization (SEO))
# 41    0.036                         (Short Video Ads)
# 42    0.036                (Social Media Advertising)
# 43    0.078                     (Social Media Design)
# 44    0.116                  (Social Media Marketing)
# 45    0.040                            (Support & IT)
# 46    0.028                  (T-Shirts & Merchandise)
# 47    0.038                             (Translation)
# 48    0.022                          (Vector Tracing)
# 49    0.028                           (Video Editing)
# 50    0.052                       (Virtual Assistant)
# 51    0.034                              (Voice Over)
# 52    0.072                           (Web Analytics)
# 53    0.066                         (Web Programming)
# 54    0.034                  (Website Builders & CMS)
# 55    0.036                         (Website Content)
# 56    0.030                          (Website Design)
# 57    0.060        (Whiteboard & Animated Explainers)
# 58    0.150                               (WordPress)
# 59    0.022  (Articles & Blog Posts, Website Content)

# %%
overal_association_rules = association_rules(freq_itemset_support, metric="confidence", min_threshold=0.50)
overal_association_rules
# Out:
#                       antecedents                         consequents  \
# 0               (Website Content)             (Articles & Blog Posts)
# 1            (Brand Style Guides)                       (Logo Design)
# 2               (Brochure Design)                      (Flyer Design)
# 3   (Business Cards & Stationery)                       (Logo Design)
# 4                         (Sales)                        (Data Entry)
# 5             (Virtual Assistant)                        (Data Entry)
# 6            (Data Visualization)                      (Data Science)
# 7        (E-Commerce Development)                         (WordPress)
# 8                  (Flyer Design)                       (Logo Design)
# 9                  (Flyer Design)               (Social Media Design)
# 10       (Graphics for Streamers)                       (Logo Design)
# 11       (T-Shirts & Merchandise)                       (Logo Design)
# 12           (Marketing Strategy)            (Social Media Marketing)
# 13              (Short Video Ads)  (Whiteboard & Animated Explainers)
# 14       (Website Builders & CMS)                         (WordPress)
#
#     antecedent support  consequent support  support  confidence       lift  \
# 0                0.036               0.082    0.022    0.611111   7.452575
# 1                0.050               0.162    0.046    0.920000   5.679012
# 2                0.032               0.054    0.026    0.812500  15.046296
# 3                0.040               0.162    0.024    0.600000   3.703704
# 4                0.034               0.092    0.026    0.764706   8.312020
# 5                0.052               0.092    0.032    0.615385   6.688963
# 6                0.034               0.054    0.020    0.588235  10.893246
# 7                0.068               0.150    0.034    0.500000   3.333333
# 8                0.054               0.162    0.032    0.592593   3.657979
# 9                0.054               0.078    0.028    0.518519   6.647673
# 10               0.032               0.162    0.022    0.687500   4.243827
# 11               0.028               0.162    0.020    0.714286   4.409171
# 12               0.038               0.116    0.022    0.578947   4.990926
# 13               0.036               0.060    0.022    0.611111  10.185185
# 14               0.034               0.150    0.022    0.647059   4.313725
#
#     leverage  conviction
# 0   0.019048    2.360571
# 1   0.037900   10.475000
# 2   0.024272    5.045333
# 3   0.017520    2.095000
# 4   0.022872    3.859000
# 5   0.027216    2.360800
# 6   0.018164    2.297429
# 7   0.023800    1.700000
# 8   0.023252    2.056909
# 9   0.023788    1.914923
# 10  0.016816    2.681600
# 11  0.015464    2.933000
# 12  0.017592    2.099500
# 13  0.019840    2.417143
# 14  0.016900    2.408333

# %%
#overal_association_rules = association_rules(freq_itemset_support, metric="lift", min_threshold=1.0)
#overal_association_rules
plt.figure(figsize=(10,6))
sns.scatterplot(x = "support", y = "confidence", data = overal_association_rules)
plt.margins(0.01,0.01)
plt.show()

# %%
# Convert antecedents and consequents into strings
overal_association_rules['antecedents'] = overal_association_rules['antecedents'].apply(lambda a: ','.join(list(a)))
overal_association_rules['consequents'] = overal_association_rules['consequents'].apply(lambda a: ','.join(list(a)))

# Transform antecedent, consequent, and support columns into matrix
support_table = overal_association_rules.pivot(index='consequents', columns='antecedents', values='support')

plt.figure(figsize=(10,6))
sns.heatmap(support_table, annot=True, cbar=False)
b, t = plt.ylim() 
b += 0.5 
t -= 0.5 
plt.ylim(b, t) 
plt.yticks(rotation=0)
plt.show()

# %%
import networkx as nx
fig, ax=plt.subplots(figsize=(40,15))
GA=nx.from_pandas_edgelist(overal_association_rules,source='antecedents',target='consequents')
nx.draw(GA,with_labels=True)
plt.show()

# %%
overal_association_rules.sort_values('confidence', ascending=False)
# Out:
#                     antecedents                       consequents  \
# 1            Brand Style Guides                       Logo Design
# 2               Brochure Design                      Flyer Design
# 4                         Sales                        Data Entry
# 11       T-Shirts & Merchandise                       Logo Design
# 10       Graphics for Streamers                       Logo Design
# 14       Website Builders & CMS                         WordPress
# 5             Virtual Assistant                        Data Entry
# 0               Website Content             Articles & Blog Posts
# 13              Short Video Ads  Whiteboard & Animated Explainers
# 3   Business Cards & Stationery                       Logo Design
# 8                  Flyer Design                       Logo Design
# 6            Data Visualization                      Data Science
# 12           Marketing Strategy            Social Media Marketing
# 9                  Flyer Design               Social Media Design
# 7        E-Commerce Development                         WordPress
#
#     antecedent support  consequent support  support  confidence       lift  \
# 1                0.050               0.162    0.046    0.920000   5.679012
# 2                0.032               0.054    0.026    0.812500  15.046296
# 4                0.034               0.092    0.026    0.764706   8.312020
# 11               0.028               0.162    0.020    0.714286   4.409171
# 10               0.032               0.162    0.022    0.687500   4.243827
# 14               0.034               0.150    0.022    0.647059   4.313725
# 5                0.052               0.092    0.032    0.615385   6.688963
# 0                0.036               0.082    0.022    0.611111   7.452575
# 13               0.036               0.060    0.022    0.611111  10.185185
# 3                0.040               0.162    0.024    0.600000   3.703704
# 8                0.054               0.162    0.032    0.592593   3.657979
# 6                0.034               0.054    0.020    0.588235  10.893246
# 12               0.038               0.116    0.022    0.578947   4.990926
# 9                0.054               0.078    0.028    0.518519   6.647673
# 7                0.068               0.150    0.034    0.500000   3.333333
#
#     leverage  conviction
# 1   0.037900   10.475000
# 2   0.024272    5.045333
# 4   0.022872    3.859000
# 11  0.015464    2.933000
# 10  0.016816    2.681600
# 14  0.016900    2.408333
# 5   0.027216    2.360800
# 0   0.019048    2.360571
# 13  0.019840    2.417143
# 3   0.017520    2.095000
# 8   0.023252    2.056909
# 6   0.018164    2.297429
# 12  0.017592    2.099500
# 9   0.023788    1.914923
# 7   0.023800    1.700000

# %%
#overal_association_rules.sort_values('lift', ascending=False)

# %% [markdown]
# # Using FP Growth

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth_frequent_itemset_1 = fpgrowth(transaction_df_subcat, min_support=0.02, use_colnames=True)
fpgrowth_frequent_itemset_1
# Out:
#     support                                           itemsets
# 0     0.092                                       (Data Entry)
# 1     0.034                                  (Data Processing)
# 2     0.030                            (E-Commerce Management)
# 3     0.150                                        (WordPress)
# 4     0.108                 (Search Engine Optimization (SEO))
# ..      ...                                                ...
# 75    0.022  (Short Video Ads, Whiteboard & Animated Explai...
# 76    0.020              (T-Shirts & Merchandise, Logo Design)
# 77    0.022       (Marketing Strategy, Social Media Marketing)
# 78    0.020                 (Data Visualization, Data Science)
# 79    0.022                (WordPress, Website Builders & CMS)
#
# [80 rows x 2 columns]

# %%
transaction_df_subcat
# Out:
#       Ad Copy  Affiliate Marketing  Album Cover Design  Animated GIFs  \
# 0       False                False               False          False
# 1       False                False               False          False
# 2       False                False               False          False
# 3       False                False               False          False
# 4       False                False               False          False
# ...       ...                  ...                 ...            ...
# 1495    False                False               False          False
# 1496    False                False               False          False
# 1497    False                False               False          False
# 1498    False                False               False          False
# 1499    False                False               False          False
#
#       Animation for Kids  Animation for Streamers  App & Website Previews  \
# 0                  False                    False                   False
# 1                  False                    False                   False
# 2                  False                    False                   False
# 3                  False                    False                   False
# 4                  False                    False                   False
# ...                  ...                      ...                     ...
# 1495               False                    False                   False
# 1496               False                    False                   False
# 1497               False                    False                   False
# 1498               False                    False                   False
# 1499               False                    False                   False
#
#       App Design  Architecture & Interior Design  Articles & Blog Posts  ...  \
# 0          False                           False                  False  ...
# 1          False                           False                  False  ...
# 2          False                           False                  False  ...
# 3          False                           False                  False  ...
# 4          False                           False                  False  ...
# ...          ...                             ...                    ...  ...
# 1495       False                           False                  False  ...
# 1496       False                           False                  False  ...
# 1497       False                           False                  False  ...
# 1498       False                           False                  False  ...
# 1499       False                           False                  False  ...
#
#       Web Traffic  Website Builders & CMS  Website Content  Website Design  \
# 0           False                   False            False           False
# 1           False                   False            False           False
# 2           False                   False            False           False
# 3            True                   False            False           False
# 4           False                   False            False           False
# ...           ...                     ...              ...             ...
# 1495        False                   False            False           False
# 1496        False                   False            False           False
# 1497        False                   False            False           False
# 1498        False                   False            False           False
# 1499        False                   False            False           False
#
#       Wellness  Whiteboard & Animated Explainers  WordPress  Wordpress  \
# 0        False                             False      False      False
# 1        False                             False       True      False
# 2        False                             False      False      False
# 3        False                             False      False      False
# 4        False                             False      False      False
# ...        ...                               ...        ...        ...
# 1495     False                             False      False      False
# 1496     False                             False      False      False
# 1497     False                             False      False      False
# 1498     False                             False       True      False
# 1499     False                             False      False      False
#
#       eLearning Content Development  eLearning Video Production
# 0                             False                       False
# 1                             False                       False
# 2                             False                       False
# 3                             False                       False
# 4                             False                       False
# ...                             ...                         ...
# 1495                          False                       False
# 1496                          False                       False
# 1497                          False                       False
# 1498                          False                       False
# 1499                          False                       False
#
# [1500 rows x 176 columns]

# %%
fpgrowth_association_rules_1 = association_rules(fpgrowth_frequent_itemset_1, metric="confidence", min_threshold=0.50)
fpgrowth_association_rules_1
# Out:
#                       antecedents                         consequents  \
# 0        (E-Commerce Development)                         (WordPress)
# 1                         (Sales)                        (Data Entry)
# 2               (Website Content)             (Articles & Blog Posts)
# 3                  (Flyer Design)                       (Logo Design)
# 4                  (Flyer Design)               (Social Media Design)
# 5   (Business Cards & Stationery)                       (Logo Design)
# 6               (Brochure Design)                      (Flyer Design)
# 7            (Brand Style Guides)                       (Logo Design)
# 8             (Virtual Assistant)                        (Data Entry)
# 9        (Graphics for Streamers)                       (Logo Design)
# 10              (Short Video Ads)  (Whiteboard & Animated Explainers)
# 11       (T-Shirts & Merchandise)                       (Logo Design)
# 12           (Marketing Strategy)            (Social Media Marketing)
# 13           (Data Visualization)                      (Data Science)
# 14       (Website Builders & CMS)                         (WordPress)
#
#     antecedent support  consequent support  support  confidence       lift  \
# 0                0.068               0.150    0.034    0.500000   3.333333
# 1                0.034               0.092    0.026    0.764706   8.312020
# 2                0.036               0.082    0.022    0.611111   7.452575
# 3                0.054               0.162    0.032    0.592593   3.657979
# 4                0.054               0.078    0.028    0.518519   6.647673
# 5                0.040               0.162    0.024    0.600000   3.703704
# 6                0.032               0.054    0.026    0.812500  15.046296
# 7                0.050               0.162    0.046    0.920000   5.679012
# 8                0.052               0.092    0.032    0.615385   6.688963
# 9                0.032               0.162    0.022    0.687500   4.243827
# 10               0.036               0.060    0.022    0.611111  10.185185
# 11               0.028               0.162    0.020    0.714286   4.409171
# 12               0.038               0.116    0.022    0.578947   4.990926
# 13               0.034               0.054    0.020    0.588235  10.893246
# 14               0.034               0.150    0.022    0.647059   4.313725
#
#     leverage  conviction
# 0   0.023800    1.700000
# 1   0.022872    3.859000
# 2   0.019048    2.360571
# 3   0.023252    2.056909
# 4   0.023788    1.914923
# 5   0.017520    2.095000
# 6   0.024272    5.045333
# 7   0.037900   10.475000
# 8   0.027216    2.360800
# 9   0.016816    2.681600
# 10  0.019840    2.417143
# 11  0.015464    2.933000
# 12  0.017592    2.099500
# 13  0.018164    2.297429
# 14  0.016900    2.408333

# %% [markdown]
# # Pricing_Sales Relations

# %%
dataset_1 = pd.read_excel('G:/4-1 Thesis/last.xlsx')

# %%
dataset_1.head()
# Out:
#                 Category                   Subcat  price  \
# 0     Programming & Tech  Data Analysis & Reports    155
# 1              Lifestyle  Greeting Cards & Videos      5
# 2     Programming & Tech   Website Builders & CMS     75
# 3              Lifestyle          Cooking Lessons     20
# 4  Writing & Translation            Legal Writing     10
#
#                   price_cat  sales                sales_cat  stars stars_cat
# 0  price between 105 to 500     10       Sales Less Than 10    5.0      Five
# 1                  Five USD   1000          Sales above 100    5.0      Five
# 2   price between 55 to 100     68  Sales between 51 to 100    5.0      Five
# 3    price_between 15 to 20      5       Sales Less Than 10    4.9     Four+
# 4                   Ten USD      2       Sales Less Than 10    5.0      Five

# %%
#np.random.seed(0)
#df = pd.DataFrame({"a": np.random.random_integers(1, high=100, size=6183)})
#ranges = [0,5,10,20,30,50,100,500,10000]
#df.groupby(pd.cut(dataset_1.sales_cat, ranges)).count()

# %%
column_list = []
for index, rows in dataset_1.iterrows():
    my_list = [rows.Category,rows.price_cat,rows.sales_cat]
    column_list.append(my_list)
#print(column_list)

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
tran_encod = TransactionEncoder()
tran_encod_list = tran_encod.fit(column_list).transform(column_list)
transaction_df = pd.DataFrame(tran_encod_list, columns=tran_encod.columns_)
transaction_df.head()
# Out:
#    Business  Digital Marketing  Five USD  Lifestyle  Music & Audio  \
# 0     False              False     False      False          False
# 1     False              False      True       True          False
# 2     False              False     False      False          False
# 3     False              False     False       True          False
# 4     False              False     False      False          False
#
#    Programming & Tech  Sales Between 21 to 50  Sales Less Than 10  \
# 0                True                   False                True
# 1               False                   False               False
# 2                True                   False               False
# 3               False                   False                True
# 4               False                   False                True
#
#    Sales above 100  Sales between 11 to 20  Sales between 51 to 100  Ten USD  \
# 0            False                   False                    False    False
# 1             True                   False                    False    False
# 2            False                   False                     True    False
# 3            False                   False                    False    False
# 4            False                   False                    False     True
#
#    Video & Animation  Writing & Translation  price above 500  \
# 0              False                  False            False
# 1              False                  False            False
# 2              False                  False            False
# 3              False                  False            False
# 4              False                   True            False
#
#    price between 105 to 500  price between 25 to 30  price between 35 to 50  \
# 0                      True                   False                   False
# 1                     False                   False                   False
# 2                     False                   False                   False
# 3                     False                   False                   False
# 4                     False                   False                   False
#
#    price between 55 to 100  price_between 15 to 20
# 0                    False                   False
# 1                    False                   False
# 2                     True                   False
# 3                    False                    True
# 4                    False                   False

# %%
item_count = {}
for col in transaction_df.columns:
    item_count[col] = transaction_df[col].sum()
item_freq_df = pd.DataFrame(data=list(item_count.values()), index=list(item_count.keys()), columns=['frequency']).sort_values(by='frequency', ascending=False)
item_freq_df.shape, item_freq_df.tail(15)
# Out:
# ((20, 1),
#                            frequency
#  Five USD                        986
#  Sales Between 21 to 50          911
#  price between 55 to 100         890
#  Ten USD                         886
#  price between 35 to 50          883
#  Lifestyle                       864
#  Programming & Tech              807
#  price between 105 to 500        791
#  Music & Audio                   768
#  Sales between 11 to 20          736
#  Business                        720
#  price between 25 to 30          668
#  Sales between 51 to 100         555
#  Digital Marketing               336
#  price above 500                  85)

# %%
plt.figure(figsize=(16,7))
sns.barplot(y=item_freq_df.index[:15], x=item_freq_df.frequency[:15])
plt.xticks(rotation=90)
# Out:
# (array([   0.,  500., 1000., 1500., 2000., 2500., 3000., 3500.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
apriori(transaction_df, min_support=0.0067, use_colnames=True)
# Out:
#       support                                           itemsets
# 0    0.116448                                         (Business)
# 1    0.054343                                (Digital Marketing)
# 2    0.159470                                         (Five USD)
# 3    0.139738                                        (Lifestyle)
# 4    0.124212                                    (Music & Audio)
# ..        ...                                                ...
# 169  0.023613  (Writing & Translation, price_between 15 to 20...
# 170  0.008572  (Video & Animation, price between 105 to 500, ...
# 171  0.008248  (Video & Animation, Sales above 100, price bet...
# 172  0.007278  (Video & Animation, Sales above 100, price bet...
# 173  0.007925  (Writing & Translation, Sales above 100, price...
#
# [174 rows x 2 columns]

# %%
print(f'freq>30: {item_freq_df[item_freq_df.frequency>47].shape[0]} items')
print(f'freq>20: {item_freq_df[item_freq_df.frequency>24].shape[0]} items')
print(f'freq>12: {item_freq_df[item_freq_df.frequency>12].shape[0]} items')
# Out:
# freq>30: 20 items
# freq>20: 20 items
# freq>12: 20 items

# %%
freq_itemset_support = apriori(transaction_df, min_support=0.005, use_colnames=True)
freq_itemset_support
# Out:
#       support                                           itemsets
# 0    0.116448                                         (Business)
# 1    0.054343                                (Digital Marketing)
# 2    0.159470                                         (Five USD)
# 3    0.139738                                        (Lifestyle)
# 4    0.124212                                    (Music & Audio)
# ..        ...                                                ...
# 190  0.005014  (Writing & Translation, Sales above 100, price...
# 191  0.005337  (Writing & Translation, Sales above 100, price...
# 192  0.007925  (Writing & Translation, Sales above 100, price...
# 193  0.005337  (Writing & Translation, price between 35 to 50...
# 194  0.005014  (Writing & Translation, Sales between 51 to 10...
#
# [195 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import apriori

apriori(transaction_df, min_support=0.005, use_colnames=True)
# Out:
#       support                                           itemsets
# 0    0.116448                                         (Business)
# 1    0.054343                                (Digital Marketing)
# 2    0.159470                                         (Five USD)
# 3    0.139738                                        (Lifestyle)
# 4    0.124212                                    (Music & Audio)
# ..        ...                                                ...
# 190  0.005014  (Writing & Translation, Sales above 100, price...
# 191  0.005337  (Writing & Translation, Sales above 100, price...
# 192  0.007925  (Writing & Translation, Sales above 100, price...
# 193  0.005337  (Writing & Translation, price between 35 to 50...
# 194  0.005014  (Writing & Translation, Sales between 51 to 10...
#
# [195 rows x 2 columns]

# %%
rules = association_rules(freq_itemset_support, metric="confidence", min_threshold=0.40)
rules
# Out:
#                                         antecedents           consequents  \
# 0                                        (Business)  (Sales Less Than 10)
# 1                               (Digital Marketing)  (Sales Less Than 10)
# 2                                        (Five USD)  (Sales Less Than 10)
# 3                                       (Lifestyle)  (Sales Less Than 10)
# 4                                   (Music & Audio)  (Sales Less Than 10)
# 5                              (Programming & Tech)  (Sales Less Than 10)
# 6                                         (Ten USD)  (Sales Less Than 10)
# 7                               (Video & Animation)  (Sales Less Than 10)
# 8                           (Writing & Translation)  (Sales Less Than 10)
# 9                                 (price above 500)  (Sales Less Than 10)
# 10                       (price between 105 to 500)  (Sales Less Than 10)
# 11                         (price between 25 to 30)  (Sales Less Than 10)
# 12                        (price between 55 to 100)  (Sales Less Than 10)
# 13                         (price_between 15 to 20)  (Sales Less Than 10)
# 14                             (Five USD, Business)  (Sales Less Than 10)
# 15                              (Business, Ten USD)  (Sales Less Than 10)
# 16             (price between 105 to 500, Business)  (Sales Less Than 10)
# 17               (price between 25 to 30, Business)  (Sales Less Than 10)
# 18              (Business, price between 55 to 100)  (Sales Less Than 10)
# 19               (price_between 15 to 20, Business)  (Sales Less Than 10)
# 20                            (Five USD, Lifestyle)  (Sales Less Than 10)
# 21                  (Lifestyle, Sales Less Than 10)            (Five USD)
# 22                        (Five USD, Music & Audio)  (Sales Less Than 10)
# 23                   (Five USD, Programming & Tech)  (Sales Less Than 10)
# 24                    (Video & Animation, Five USD)  (Sales Less Than 10)
# 25                (Five USD, Writing & Translation)  (Sales Less Than 10)
# 26                             (Lifestyle, Ten USD)  (Sales Less Than 10)
# 27              (Lifestyle, price between 35 to 50)  (Sales Less Than 10)
# 28              (price_between 15 to 20, Lifestyle)  (Sales Less Than 10)
# 29                         (Music & Audio, Ten USD)  (Sales Less Than 10)
# 30          (price between 25 to 30, Music & Audio)  (Sales Less Than 10)
# 31          (Music & Audio, price_between 15 to 20)  (Sales Less Than 10)
# 32                    (Ten USD, Programming & Tech)  (Sales Less Than 10)
# 33   (price between 105 to 500, Programming & Tech)  (Sales Less Than 10)
# 34    (price between 55 to 100, Programming & Tech)  (Sales Less Than 10)
# 35                     (Video & Animation, Ten USD)  (Sales Less Than 10)
# 36                 (Writing & Translation, Ten USD)  (Sales Less Than 10)
# 37    (Video & Animation, price between 105 to 500)  (Sales Less Than 10)
# 38     (Video & Animation, price between 55 to 100)  (Sales Less Than 10)
# 39  (price between 25 to 30, Writing & Translation)  (Sales Less Than 10)
# 40  (Writing & Translation, price between 35 to 50)  (Sales Less Than 10)
# 41  (Writing & Translation, price_between 15 to 20)  (Sales Less Than 10)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.116448            0.475497  0.054504    0.468056  0.984349
# 1             0.054343            0.475497  0.022481    0.413690  0.870016
# 2             0.159470            0.475497  0.096070    0.602434  1.266956
# 3             0.139738            0.475497  0.078764    0.563657  1.185406
# 4             0.124212            0.475497  0.051593    0.415365  0.873537
# 5             0.130519            0.475497  0.060488    0.463445  0.974653
# 6             0.143296            0.475497  0.076015    0.530474  1.115619
# 7             0.201844            0.475497  0.089115    0.441506  0.928515
# 8             0.232897            0.475497  0.118551    0.509028  1.070517
# 9             0.013747            0.475497  0.008895    0.647059  1.360804
# 10            0.127931            0.475497  0.058224    0.455120  0.957145
# 11            0.108038            0.475497  0.045124    0.417665  0.878374
# 12            0.143943            0.475497  0.057739    0.401124  0.843587
# 13            0.160763            0.475497  0.078279    0.486922  1.024026
# 14            0.013747            0.475497  0.006469    0.470588  0.989676
# 15            0.013424            0.475497  0.006631    0.493976  1.038862
# 16            0.016012            0.475497  0.007925    0.494949  1.040909
# 17            0.015688            0.475497  0.007440    0.474227  0.997328
# 18            0.018276            0.475497  0.008248    0.451327  0.949169
# 19            0.019246            0.475497  0.009704    0.504202  1.060367
# 20            0.045447            0.475497  0.031700    0.697509  1.466904
# 21            0.078764            0.159470  0.031700    0.402464  2.523768
# 22            0.017629            0.475497  0.010027    0.568807  1.196237
# 23            0.016820            0.475497  0.008895    0.528846  1.112196
# 24            0.024422            0.475497  0.014556    0.596026  1.253480
# 25            0.034611            0.475497  0.020702    0.598131  1.257906
# 26            0.033641            0.475497  0.017791    0.528846  1.112196
# 27            0.012292            0.475497  0.006793    0.552632  1.162218
# 28            0.028627            0.475497  0.014718    0.514124  1.081235
# 29            0.017629            0.475497  0.007763    0.440367  0.926119
# 30            0.018599            0.475497  0.008410    0.452174  0.950949
# 31            0.022966            0.475497  0.010836    0.471831  0.992289
# 32            0.019732            0.475497  0.010189    0.516393  1.086007
# 33            0.025392            0.475497  0.012615    0.496815  1.044833
# 34            0.018761            0.475497  0.008087    0.431034  0.906492
# 35            0.020702            0.475497  0.010998    0.531250  1.117251
# 36            0.031215            0.475497  0.018599    0.595855  1.253119
# 37            0.039140            0.475497  0.018438    0.471074  0.990698
# 38            0.035905            0.475497  0.014880    0.414414  0.871539
# 39            0.020217            0.475497  0.009866    0.488000  1.026294
# 40            0.034611            0.475497  0.016659    0.481308  1.012221
# 41            0.039463            0.475497  0.023613    0.598361  1.258389
#
#     leverage  conviction
# 0  -0.000867    0.986010
# 1  -0.003359    0.894583
# 2   0.020243    1.319285
# 3   0.012319    1.202043
# 4  -0.007469    0.897145
# 5  -0.001573    0.977537
# 6   0.007878    1.117090
# 7  -0.006861    0.939138
# 8   0.007809    1.068294
# 9   0.002359    1.486091
# 10 -0.002607    0.962602
# 11 -0.006248    0.900688
# 12 -0.010706    0.875811
# 13  0.001837    1.022266
# 14 -0.000067    0.990727
# 15  0.000248    1.036517
# 16  0.000311    1.038515
# 17 -0.000020    0.997584
# 18 -0.000442    0.955948
# 19  0.000552    1.057895
# 20  0.010090    1.733944
# 21  0.019139    1.406661
# 22  0.001645    1.216400
# 23  0.000897    1.113230
# 24  0.002944    1.298359
# 25  0.004244    1.305158
# 26  0.001795    1.113230
# 27  0.000948    1.172418
# 28  0.001106    1.079500
# 29 -0.000619    0.937226
# 30 -0.000434    0.957426
# 31 -0.000084    0.993058
# 32  0.000807    1.084565
# 33  0.000541    1.042366
# 34 -0.000834    0.921853
# 35  0.001154    1.118939
# 36  0.003757    1.297808
# 37 -0.000173    0.991638
# 38 -0.002193    0.895689
# 39  0.000253    1.024419
# 40  0.000201    1.011203
# 41  0.004849    1.305905

# %%
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules
# Out:
#                                         antecedents           consequents  \
# 0                                        (Business)  (Sales Less Than 10)
# 1                               (Digital Marketing)  (Sales Less Than 10)
# 2                                        (Five USD)  (Sales Less Than 10)
# 3                                       (Lifestyle)  (Sales Less Than 10)
# 4                                   (Music & Audio)  (Sales Less Than 10)
# 5                              (Programming & Tech)  (Sales Less Than 10)
# 6                                         (Ten USD)  (Sales Less Than 10)
# 7                               (Video & Animation)  (Sales Less Than 10)
# 8                           (Writing & Translation)  (Sales Less Than 10)
# 9                                 (price above 500)  (Sales Less Than 10)
# 10                       (price between 105 to 500)  (Sales Less Than 10)
# 11                         (price between 25 to 30)  (Sales Less Than 10)
# 12                        (price between 55 to 100)  (Sales Less Than 10)
# 13                         (price_between 15 to 20)  (Sales Less Than 10)
# 14                             (Five USD, Business)  (Sales Less Than 10)
# 15                              (Business, Ten USD)  (Sales Less Than 10)
# 16             (price between 105 to 500, Business)  (Sales Less Than 10)
# 17               (price between 25 to 30, Business)  (Sales Less Than 10)
# 18              (Business, price between 55 to 100)  (Sales Less Than 10)
# 19               (price_between 15 to 20, Business)  (Sales Less Than 10)
# 20                            (Five USD, Lifestyle)  (Sales Less Than 10)
# 21                  (Lifestyle, Sales Less Than 10)            (Five USD)
# 22                        (Five USD, Music & Audio)  (Sales Less Than 10)
# 23                   (Five USD, Programming & Tech)  (Sales Less Than 10)
# 24                    (Video & Animation, Five USD)  (Sales Less Than 10)
# 25                (Five USD, Writing & Translation)  (Sales Less Than 10)
# 26                             (Lifestyle, Ten USD)  (Sales Less Than 10)
# 27              (Lifestyle, price between 35 to 50)  (Sales Less Than 10)
# 28              (price_between 15 to 20, Lifestyle)  (Sales Less Than 10)
# 29                         (Music & Audio, Ten USD)  (Sales Less Than 10)
# 30          (price between 25 to 30, Music & Audio)  (Sales Less Than 10)
# 31          (Music & Audio, price_between 15 to 20)  (Sales Less Than 10)
# 32                    (Ten USD, Programming & Tech)  (Sales Less Than 10)
# 33   (price between 105 to 500, Programming & Tech)  (Sales Less Than 10)
# 34    (price between 55 to 100, Programming & Tech)  (Sales Less Than 10)
# 35                     (Video & Animation, Ten USD)  (Sales Less Than 10)
# 36                 (Writing & Translation, Ten USD)  (Sales Less Than 10)
# 37    (Video & Animation, price between 105 to 500)  (Sales Less Than 10)
# 38     (Video & Animation, price between 55 to 100)  (Sales Less Than 10)
# 39  (price between 25 to 30, Writing & Translation)  (Sales Less Than 10)
# 40  (Writing & Translation, price between 35 to 50)  (Sales Less Than 10)
# 41  (Writing & Translation, price_between 15 to 20)  (Sales Less Than 10)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.116448            0.475497  0.054504    0.468056  0.984349
# 1             0.054343            0.475497  0.022481    0.413690  0.870016
# 2             0.159470            0.475497  0.096070    0.602434  1.266956
# 3             0.139738            0.475497  0.078764    0.563657  1.185406
# 4             0.124212            0.475497  0.051593    0.415365  0.873537
# 5             0.130519            0.475497  0.060488    0.463445  0.974653
# 6             0.143296            0.475497  0.076015    0.530474  1.115619
# 7             0.201844            0.475497  0.089115    0.441506  0.928515
# 8             0.232897            0.475497  0.118551    0.509028  1.070517
# 9             0.013747            0.475497  0.008895    0.647059  1.360804
# 10            0.127931            0.475497  0.058224    0.455120  0.957145
# 11            0.108038            0.475497  0.045124    0.417665  0.878374
# 12            0.143943            0.475497  0.057739    0.401124  0.843587
# 13            0.160763            0.475497  0.078279    0.486922  1.024026
# 14            0.013747            0.475497  0.006469    0.470588  0.989676
# 15            0.013424            0.475497  0.006631    0.493976  1.038862
# 16            0.016012            0.475497  0.007925    0.494949  1.040909
# 17            0.015688            0.475497  0.007440    0.474227  0.997328
# 18            0.018276            0.475497  0.008248    0.451327  0.949169
# 19            0.019246            0.475497  0.009704    0.504202  1.060367
# 20            0.045447            0.475497  0.031700    0.697509  1.466904
# 21            0.078764            0.159470  0.031700    0.402464  2.523768
# 22            0.017629            0.475497  0.010027    0.568807  1.196237
# 23            0.016820            0.475497  0.008895    0.528846  1.112196
# 24            0.024422            0.475497  0.014556    0.596026  1.253480
# 25            0.034611            0.475497  0.020702    0.598131  1.257906
# 26            0.033641            0.475497  0.017791    0.528846  1.112196
# 27            0.012292            0.475497  0.006793    0.552632  1.162218
# 28            0.028627            0.475497  0.014718    0.514124  1.081235
# 29            0.017629            0.475497  0.007763    0.440367  0.926119
# 30            0.018599            0.475497  0.008410    0.452174  0.950949
# 31            0.022966            0.475497  0.010836    0.471831  0.992289
# 32            0.019732            0.475497  0.010189    0.516393  1.086007
# 33            0.025392            0.475497  0.012615    0.496815  1.044833
# 34            0.018761            0.475497  0.008087    0.431034  0.906492
# 35            0.020702            0.475497  0.010998    0.531250  1.117251
# 36            0.031215            0.475497  0.018599    0.595855  1.253119
# 37            0.039140            0.475497  0.018438    0.471074  0.990698
# 38            0.035905            0.475497  0.014880    0.414414  0.871539
# 39            0.020217            0.475497  0.009866    0.488000  1.026294
# 40            0.034611            0.475497  0.016659    0.481308  1.012221
# 41            0.039463            0.475497  0.023613    0.598361  1.258389
#
#     leverage  conviction  antecedent_len
# 0  -0.000867    0.986010               1
# 1  -0.003359    0.894583               1
# 2   0.020243    1.319285               1
# 3   0.012319    1.202043               1
# 4  -0.007469    0.897145               1
# 5  -0.001573    0.977537               1
# 6   0.007878    1.117090               1
# 7  -0.006861    0.939138               1
# 8   0.007809    1.068294               1
# 9   0.002359    1.486091               1
# 10 -0.002607    0.962602               1
# 11 -0.006248    0.900688               1
# 12 -0.010706    0.875811               1
# 13  0.001837    1.022266               1
# 14 -0.000067    0.990727               2
# 15  0.000248    1.036517               2
# 16  0.000311    1.038515               2
# 17 -0.000020    0.997584               2
# 18 -0.000442    0.955948               2
# 19  0.000552    1.057895               2
# 20  0.010090    1.733944               2
# 21  0.019139    1.406661               2
# 22  0.001645    1.216400               2
# 23  0.000897    1.113230               2
# 24  0.002944    1.298359               2
# 25  0.004244    1.305158               2
# 26  0.001795    1.113230               2
# 27  0.000948    1.172418               2
# 28  0.001106    1.079500               2
# 29 -0.000619    0.937226               2
# 30 -0.000434    0.957426               2
# 31 -0.000084    0.993058               2
# 32  0.000807    1.084565               2
# 33  0.000541    1.042366               2
# 34 -0.000834    0.921853               2
# 35  0.001154    1.118939               2
# 36  0.003757    1.297808               2
# 37 -0.000173    0.991638               2
# 38 -0.002193    0.895689               2
# 39  0.000253    1.024419               2
# 40  0.000201    1.011203               2
# 41  0.004849    1.305905               2

# %%
rules[ (rules['antecedent_len'] >= 2) &
       (rules['confidence'] > 0.4) &
       (rules['lift'] > 1.0) ]
# Out:
#                                         antecedents           consequents  \
# 15                              (Business, Ten USD)  (Sales Less Than 10)
# 16             (price between 105 to 500, Business)  (Sales Less Than 10)
# 19               (price_between 15 to 20, Business)  (Sales Less Than 10)
# 20                            (Five USD, Lifestyle)  (Sales Less Than 10)
# 21                  (Lifestyle, Sales Less Than 10)            (Five USD)
# 22                        (Five USD, Music & Audio)  (Sales Less Than 10)
# 23                   (Five USD, Programming & Tech)  (Sales Less Than 10)
# 24                    (Video & Animation, Five USD)  (Sales Less Than 10)
# 25                (Five USD, Writing & Translation)  (Sales Less Than 10)
# 26                             (Lifestyle, Ten USD)  (Sales Less Than 10)
# 27              (Lifestyle, price between 35 to 50)  (Sales Less Than 10)
# 28              (price_between 15 to 20, Lifestyle)  (Sales Less Than 10)
# 32                    (Ten USD, Programming & Tech)  (Sales Less Than 10)
# 33   (price between 105 to 500, Programming & Tech)  (Sales Less Than 10)
# 35                     (Video & Animation, Ten USD)  (Sales Less Than 10)
# 36                 (Writing & Translation, Ten USD)  (Sales Less Than 10)
# 39  (price between 25 to 30, Writing & Translation)  (Sales Less Than 10)
# 40  (Writing & Translation, price between 35 to 50)  (Sales Less Than 10)
# 41  (Writing & Translation, price_between 15 to 20)  (Sales Less Than 10)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 15            0.013424            0.475497  0.006631    0.493976  1.038862
# 16            0.016012            0.475497  0.007925    0.494949  1.040909
# 19            0.019246            0.475497  0.009704    0.504202  1.060367
# 20            0.045447            0.475497  0.031700    0.697509  1.466904
# 21            0.078764            0.159470  0.031700    0.402464  2.523768
# 22            0.017629            0.475497  0.010027    0.568807  1.196237
# 23            0.016820            0.475497  0.008895    0.528846  1.112196
# 24            0.024422            0.475497  0.014556    0.596026  1.253480
# 25            0.034611            0.475497  0.020702    0.598131  1.257906
# 26            0.033641            0.475497  0.017791    0.528846  1.112196
# 27            0.012292            0.475497  0.006793    0.552632  1.162218
# 28            0.028627            0.475497  0.014718    0.514124  1.081235
# 32            0.019732            0.475497  0.010189    0.516393  1.086007
# 33            0.025392            0.475497  0.012615    0.496815  1.044833
# 35            0.020702            0.475497  0.010998    0.531250  1.117251
# 36            0.031215            0.475497  0.018599    0.595855  1.253119
# 39            0.020217            0.475497  0.009866    0.488000  1.026294
# 40            0.034611            0.475497  0.016659    0.481308  1.012221
# 41            0.039463            0.475497  0.023613    0.598361  1.258389
#
#     leverage  conviction  antecedent_len
# 15  0.000248    1.036517               2
# 16  0.000311    1.038515               2
# 19  0.000552    1.057895               2
# 20  0.010090    1.733944               2
# 21  0.019139    1.406661               2
# 22  0.001645    1.216400               2
# 23  0.000897    1.113230               2
# 24  0.002944    1.298359               2
# 25  0.004244    1.305158               2
# 26  0.001795    1.113230               2
# 27  0.000948    1.172418               2
# 28  0.001106    1.079500               2
# 32  0.000807    1.084565               2
# 33  0.000541    1.042366               2
# 35  0.001154    1.118939               2
# 36  0.003757    1.297808               2
# 39  0.000253    1.024419               2
# 40  0.000201    1.011203               2
# 41  0.004849    1.305905               2

# %% [markdown]
# # Overal_Corelation for Pricing,Sales and Stars

# %%
df = pd.read_excel('G:/4-1 Thesis/last.xlsx')

# %%
correlation_df = dataset_1.corr()

# %%
display(correlation_df)
# Out:
#         price     sales     stars
# price  1.0000 -0.023400 -0.101200
# sales -0.0234  1.000000  0.122465
# stars -0.1012  0.122465  1.000000

# %% [markdown]
# # Co-relation of each category separatley

# %%
i=1
for categ in dataset_1['Category'].unique():
    print(str(i)+' - '+str(categ))
    i=i+1
# Out:
# 1 - Programming & Tech
# 2 - Lifestyle
# 3 - Writing & Translation
# 4 - Digital Marketing
# 5 - Video & Animation
# 6 - Music & Audio
# 7 - Business

# %%
df_1 = df[df['Category'] == 'Programming & Tech']
df_2 = df[df['Category'] == 'Lifestyle']
df_3 = df[df['Category'] == 'Writing & Translation']
df_4 = df[df['Category'] == 'Digital Marketing']
df_5 = df[df['Category'] == 'Video & Animation']
df_6 = df[df['Category'] == 'Music & Audio']
df_7 = df[df['Category'] == 'Business']

# %% [markdown]
# # Programming & Tech

# %%
correlation_df_1 = df_1.corr()
display(correlation_df_1)
# Out:
#           price     sales     stars
# price  1.000000 -0.047587 -0.194150
# sales -0.047587  1.000000  0.148159
# stars -0.194150  0.148159  1.000000

# %% [markdown]
# # Lifestyle

# %%
correlation_df_2 = df_2.corr()
display(correlation_df_2)
# Out:
#           price     sales     stars
# price  1.000000  0.073957  0.051180
# sales  0.073957  1.000000  0.090887
# stars  0.051180  0.090887  1.000000

# %% [markdown]
# # Writing & Translation

# %%
correlation_df_3 = df_3.corr()
display(correlation_df_3)
# Out:
#           price     sales     stars
# price  1.000000 -0.018720 -0.058871
# sales -0.018720  1.000000  0.116646
# stars -0.058871  0.116646  1.000000

# %% [markdown]
# # Digital Marketing

# %%
correlation_df_4 = df_4.corr()
display(correlation_df_4)
# Out:
#           price     sales     stars
# price  1.000000 -0.090159 -0.042002
# sales -0.090159  1.000000  0.141554
# stars -0.042002  0.141554  1.000000

# %% [markdown]
# # Video & Animation

# %%
correlation_df_5 = df_5.corr()
display(correlation_df_5)
# Out:
#           price     sales     stars
# price  1.000000 -0.041246 -0.089540
# sales -0.041246  1.000000  0.141531
# stars -0.089540  0.141531  1.000000

# %% [markdown]
# # Music & Audio

# %%
correlation_df_6 = df_6.corr()
display(correlation_df_6)
# Out:
#           price     sales     stars
# price  1.000000 -0.015457 -0.061822
# sales -0.015457  1.000000  0.112850
# stars -0.061822  0.112850  1.000000

# %% [markdown]
# # Business

# %%
correlation_df_7 = df_7.corr()
display(correlation_df_7)
# Out:
#           price     sales     stars
# price  1.000000 -0.008695 -0.117306
# sales -0.008695  1.000000  0.111292
# stars -0.117306  0.111292  1.000000
